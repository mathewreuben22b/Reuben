# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import GridSearchCV
from sklearn.impute import SimpleImputer
from sklearn.decomposition import PCA
from sklearn.feature_selection import SelectKBest, f_regression
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression, Ridge, Lasso

# %%
iris = pd.read_csv('iris_modified.csv')

# %%
import json
  
# Opening JSON file
f = open('algoparams_from_ui.json')
  
# returns JSON object as 
# a dictionary
data = json.load(f)
  
data
# Out:
# {'session_name': 'test',
#  'session_description': 'test',
#  'design_state_data': {'session_info': {'project_id': '1',
#    'experiment_id': 'kkkk-11',
#    'dataset': 'iris_modified.csv',
#    'session_name': 'test',
#    'session_description': 'test'},
#   'target': {'prediction_type': 'Regression',
#    'target': 'petal_width',
#    'type': 'regression',
#    'partitioning': True},
#   'train': {'policy': 'Split the dataset',
#    'time_variable': 'sepal_length',
#    'sampling_method': 'No sampling(whole data)',
#    'split': 'Randomly',
#    'k_fold': False,
#    'train_ratio': 0,
#    'random_seed': 0},
#   'metrics': {'optomize_model_hyperparameters_for': 'AUC',
#    'optimize_threshold_for': 'F1 Score',
#    'compute_lift_at': 0,
#    'cost_matrix_gain_for_true_prediction_true_result': 1,
#    'cost_matrix_gain_for_true_prediction_false_result': 0,
#    'cost_matrix_gain_for_false_prediction_true_result': 0,
#    'cost_matrix_gain_for_false_prediction_false_result': 0},
# ...

# %%
target_col = data['design_state_data']['target']
reg_type = target_col['prediction_type']
reg_type
target = target_col['target']

# %%
features = data['design_state_data']['feature_handling']
features
#if imp_method != 'None':
 #   imp = SimpleImputer(strategy=imp_method)
  #  data[features] = imp.fit_transform(data[features])
# Out:
# {'sepal_length': {'feature_name': 'sepal_length',
#   'is_selected': True,
#   'feature_variable_type': 'numerical',
#   'feature_details': {'numerical_handling': 'Keep as regular numerical feature',
#    'rescaling': 'No rescaling',
#    'make_derived_feats': False,
#    'missing_values': 'Impute',
#    'impute_with': 'Average of values',
#    'impute_value': 0}},
#  'sepal_width': {'feature_name': 'sepal_width',
#   'is_selected': True,
#   'feature_variable_type': 'numerical',
#   'feature_details': {'numerical_handling': 'Keep as regular numerical feature',
#    'rescaling': 'No rescaling',
#    'make_derived_feats': False,
#    'missing_values': 'Impute',
#    'impute_with': 'custom',
#    'impute_value': -1}},
#  'petal_length': {'feature_name': 'petal_length',
#   'is_selected': True,
#   'feature_variable_type': 'numerical',
#   'feature_details': {'numerical_handling': 'Keep as regular numerical feature',
#    'rescaling': 'No rescaling',
#    'make_derived_feats': False,
# ...

# %%
for i in features: 
    print(i)
    a = features[i]
    print(a)
# Out:
# sepal_length
# {'feature_name': 'sepal_length', 'is_selected': True, 'feature_variable_type': 'numerical', 'feature_details': {'numerical_handling': 'Keep as regular numerical feature', 'rescaling': 'No rescaling', 'make_derived_feats': False, 'missing_values': 'Impute', 'impute_with': 'Average of values', 'impute_value': 0}}
# sepal_width
# {'feature_name': 'sepal_width', 'is_selected': True, 'feature_variable_type': 'numerical', 'feature_details': {'numerical_handling': 'Keep as regular numerical feature', 'rescaling': 'No rescaling', 'make_derived_feats': False, 'missing_values': 'Impute', 'impute_with': 'custom', 'impute_value': -1}}
# petal_length
# {'feature_name': 'petal_length', 'is_selected': True, 'feature_variable_type': 'numerical', 'feature_details': {'numerical_handling': 'Keep as regular numerical feature', 'rescaling': 'No rescaling', 'make_derived_feats': False, 'missing_values': 'Impute', 'impute_with': 'Average of values', 'impute_value': 0}}
# petal_width
# ...

# %% [markdown]
# # Imputation

# %%
iris['sepal_width'].fillna(-1, inplace=True)
iris['sepal_length'].fillna(0, inplace=True)
iris['petal_width'].fillna(-2, inplace=True)
iris['petal_length'].fillna(0, inplace=True)

# %% [markdown]
# ## Feature Reduction

# %%
X = iris.drop(target, axis=1)
y = iris[target]
X
# Out:
#      sepal_length  sepal_width  petal_length         species
# 0             5.1          3.5           1.4     Iris-setosa
# 1             4.9          3.0           1.4     Iris-setosa
# 2             4.7          3.2           1.3     Iris-setosa
# 3             4.6          3.1           1.5     Iris-setosa
# 4             5.0          3.6           1.4     Iris-setosa
# ..            ...          ...           ...             ...
# 145           6.7          3.0           5.2  Iris-virginica
# 146           6.3          2.5           5.0  Iris-virginica
# 147           6.5          3.0           5.2  Iris-virginica
# 148           6.2          3.4           5.4  Iris-virginica
# 149           5.9          3.0           5.1  Iris-virginica
#
# [150 rows x 4 columns]

# %%
import numpy as np
from sklearn.decomposition import PCA

# Initializing the PCA model and fitting the data
pca = PCA(n_components=2)
pca.fit(X)

# Transforming the data to its principal components
X_pca = pca.transform(X)

# Printing the transformed data
print(X_pca)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9224\668143633.py in <module>
#       4 # Initializing the PCA model and fitting the data
#       5 pca = PCA(n_components=2)
# ----> 6 pca.fit(X)
#       7
#       8 # Transforming the data to its principal components
#
# ~\anaconda3\lib\site-packages\sklearn\decomposition\_pca.py in fit(self, X, y)
#     433         self._validate_params()
#     434
# --> 435         self._fit(X)
#     436         return self
#     437
#
# ~\anaconda3\lib\site-packages\sklearn\decomposition\_pca.py in _fit(self, X)
#     483             )
#     484
# --> 485         X = self._validate_data(
#     486             X, dtype=[np.float64, np.float32], ensure_2d=True, copy=self.copy
#     487         )
#
# ...
